# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data =  sns.load_dataset('penguins')
data.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data)
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'sex')
plt.show()

# %%
# hue parameter
plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'island')
plt.show()

# %%
# size parameter
plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'sex', size = 90)
plt.show()

# %%
# style parameter
plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'sex', style ='sex')
plt.show()

# %%
# palrtte parameter required an argument (Accent)
# it is used for change color 
plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'sex', palette = 'Accent')
plt.show()

# %%
# Marker

plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'sex', marker = 'o')
plt.show()

# %%
# Dash

plt.figure(figsize = (5, 3))
sns.lineplot(x = 'bill_length_mm', y= 'bill_depth_mm', data = data, hue = 'sex')
plt.show()

# %% [markdown]
# # Histogram

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
data =  sns.load_dataset('penguins')
data.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.figure(figsize = (5, 3))
sns.distplot(data['bill_depth_mm'], color = 'r')
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.distplot(data['bill_depth_mm'],rug = True,  color = 'r')
plt.show()

# %% [markdown]
# # BarPlot

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex')
plt.show()

# %%
plt.figure(figsize = (5, 3))
order = ['Dream', 'Torgesen', 'Biscoeisland']
sns.barplot(x =data.island, y = data.bill_length_mm, data = data , 
            hue = 'sex', order = order, hue_order = ['Female', 'Male'], orient = 'v' )
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex', orient = 'v')
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.bill_length_mm, y = data.bill_length_mm, data = data ,hue = 'sex', orient = 'h')
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex',  color = 'r')
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex',  color = 'r',
palette = 'icefire')
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex',  color = 'r' , saturation = 0.3)
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex',  color = 'r', errcolor = 'r', errwidth = '10')
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex',  color = 'r', alpha = 0.3)
plt.show()

# %%
# Capsize

plt.figure(figsize = (5, 3))
sns.barplot(x =data.island, y = data.bill_length_mm, data = data ,hue = 'sex',  color = 'r', alpha = 0.3, capsize = 0.1)
plt.show()

# %% [markdown]
# # Scatter plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize = (5, 3))


data =  sns.load_dataset('penguins')
data.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.figure(figsize = (5, 3))
sns.scatterplot(x = 'bill_length_mm', y ='bill_depth_mm' , data = data, hue = 'sex', style = 'sex', size = 'sex', sizes = (100, 40))
plt.show()

# %%
plt.figure(figsize = (5, 3))
sns.scatterplot(x = 'bill_length_mm', y ='bill_depth_mm' , data = data, hue = 'sex', style = 'sex',palette = 'gist_ncar' )
plt.show()

# %%
plt.figure(figsize = (5, 3))
m = {'Male':'*', 'Female' : 'o'}
sns.scatterplot(x = 'bill_length_mm', y ='bill_depth_mm' , data = data, hue = 'sex', style = 'sex',palette = 'gist_ncar' , markers = m)
plt.show()

# %% [markdown]
# # Heat Map

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
var = np.linspace(1, 10, 20).reshape(4, 5)
var
# Out:
# array([[ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684],
#        [ 3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789],
#        [ 5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895],
#        [ 8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]])

# %%
sns.heatmap(var, vmin = 0, vmax = 20, cmap = 'gist_heat', annot = True)
# Out:
# <Axes: >

# %%
new = np.linspace(1, 10, 10).reshape(2, 5)
sns.heatmap(new, vmax= 10, vmin = 0, cmap = 'gist_heat', annot = True)
# Out:
# <Axes: >

# %%
y = {'fontsize' : 20, 'color':'g'}
sns.heatmap(new, vmax= 10, vmin = 0, cmap = 'gist_heat', annot = True, annot_kws= y, linewidth = 8, linecolor = 'g', 
           cbar = False, xticklabels = False, yticklabels = False)
sns.set(font_scale = 5)
plt.show()

# %%
data = sns.load_dataset('anagrams')
new = data.drop(columns= ['attnr'], axis = 1)
new
# Out:
#     subidr  num1  num2  num3
# 0        1     2   4.0     7
# 1        2     3   4.0     5
# 2        3     3   5.0     6
# 3        4     5   7.0     5
# 4        5     4   5.0     8
# 5        6     5   5.0     6
# 6        7     5   4.5     6
# 7        8     5   7.0     8
# 8        9     2   3.0     7
# 9       10     6   5.0     6
# 10      11     6   5.0     6
# 11      12     8   9.0     8
# 12      13     6   5.0     9
# 13      14     8   8.0     7
# 14      15     8   8.0     7
# 15      16     6   8.0     7
# 16      17     7   7.0     6
# 17      18     7   8.0     6
# 18      19     5   6.0     6
# 19      20     6   6.0     5

# %%
sns.heatmap(new, vmin = 0, vmax =12)
# Out:
# <Axes: >

# %%
arr = np.array(new)
arr
# Out:
# array([[ 1. ,  2. ,  4. ,  7. ],
#        [ 2. ,  3. ,  4. ,  5. ],
#        [ 3. ,  3. ,  5. ,  6. ],
#        [ 4. ,  5. ,  7. ,  5. ],
#        [ 5. ,  4. ,  5. ,  8. ],
#        [ 6. ,  5. ,  5. ,  6. ],
#        [ 7. ,  5. ,  4.5,  6. ],
#        [ 8. ,  5. ,  7. ,  8. ],
#        [ 9. ,  2. ,  3. ,  7. ],
#        [10. ,  6. ,  5. ,  6. ],
#        [11. ,  6. ,  5. ,  6. ],
#        [12. ,  8. ,  9. ,  8. ],
#        [13. ,  6. ,  5. ,  9. ],
#        [14. ,  8. ,  8. ,  7. ],
#        [15. ,  8. ,  8. ,  7. ],
#        [16. ,  6. ,  8. ,  7. ],
#        [17. ,  7. ,  7. ,  6. ],
#        [18. ,  7. ,  8. ,  6. ],
#        [19. ,  5. ,  6. ,  6. ],
#        [20. ,  6. ,  6. ,  5. ]])
